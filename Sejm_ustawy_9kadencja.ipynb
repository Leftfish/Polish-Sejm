# %%
import csv
import re
import requests
from collections import defaultdict
from xml.etree import ElementTree as ET
from time import sleep

# %%
REGEX_TAGS_TO_REMOVE = r'<tbody class="\w+">|<.?tbody>|<.?thead>|&nbsp;|<caption .*</caption>|<a href=".+">|<\\a>'
REGEX_VOTING_TABLE = r'<table class="kluby">.+</table>'
REGEX_CLUBS = r'<a href="agent.xsp\?symbol=klubglos&IdGlosowania=\d+&KodKlubu=\w+\-?\w+\.?"><strong>(\w+\-?\w+\.?)</strong></a>'
REGEX_VOTES = r'<a href="agent.xsp\?symbol=klubdecglos&IdGlosowania=\d+&KodKlubu=\w+\-?\w+\.?&Decyzja=\w+"><strong>(\d+)</strong></a>'
REGEX_VOTE_URL = r'<a class="vote" href="(\w+\.\w+\?symbol=glosowania&nrkadencji=\d+&nrposiedzenia=\d+&nrglosowania=\d+)">\(głos\.\s\w+\s\d+\)</a></p><p>Decyzja: uchwalono</p>'
REGEX_STATUTE = r'PrzebiegProc\.xsp\?nr=\d+'

# %%
HEADER_PARTY = 'Klub'
HEADER_TOTAL = 'Liczba'
HEADER_VOTED = 'Glosowalo'
HEADER_FOR = 'Za'
HEADER_AGAINST = 'Przeciw'
HEADER_ABSTAINED = 'Wstrzym'
TRANSLATION_TABLE = {'</td></td>': '</td></tr>', 'Klub/Koło': HEADER_PARTY, 'Liczba czł.': HEADER_TOTAL, 'Głosowało': HEADER_VOTED, ' Za ': HEADER_FOR, 'Przeciw': HEADER_AGAINST, 'Wstrzymało się': HEADER_ABSTAINED, 'Nie głosowało': HEADER_ABSTAINED}

URL_PATTERN = 'https://www.sejm.gov.pl/Sejm9.nsf/{}'

# %%
THRESHOLD = 0.65

# %%
def clean_table(s):
    for phrase in TRANSLATION_TABLE:
        s = re.sub(phrase, TRANSLATION_TABLE[phrase], s)

    for group in re.findall(REGEX_TAGS_TO_REMOVE, s):
        s = re.sub(group, '', s)
    
    s = re.sub(REGEX_CLUBS, r'\1', s)
    s = re.sub(REGEX_VOTES, r'\1', s)
    
    return s

# %%
def get_voting_results(cleaned_table):
    ### Adapted from: https://stackoverflow.com/a/7315891 CC-BY-SA 4.0
    res = []
    table = ET.XML(cleaned_table)
    rows = iter(table)
    headers = [col.text for col in next(rows)]
    for row in rows:
        values = [int(col.text) if col.text.isdigit() else col.text for col in row]
        for i in range(len(values)):
            if values[i] == '-':
                values[i] = 0
        res.append(dict(zip(headers, values)))
    return res

# %%
def get_voting_table(page):
    return re.findall(REGEX_VOTING_TABLE, page)[0]

# %%
def get_table_for_against(results):
    table_for_against = {}

    for club in results:
        members = club[HEADER_TOTAL]
        votes_for = club[HEADER_FOR]
        votes_total = club[HEADER_VOTED]
        res = votes_for >= votes_total * THRESHOLD and votes_total >= members * THRESHOLD
        table_for_against[club[HEADER_PARTY]] = res

    return table_for_against

# %%
def voted_with(table, who):
    co_voters = []
    expected = table[who]
    for party in table:
        if party != who and table[party] == expected:
            co_voters.append(party)
    return co_voters

# %%
def get_voting_page(statute_url):
    statute_page = requests.get(statute_url).text
    sleep(0.5)
    url_end = re.findall(REGEX_VOTE_URL, statute_page)[0]
    url = URL_PATTERN.format(url_end)
    voting_page = requests.get(url).text
    return voting_page

# %%
def get_voting_page_results(voting_page):
    page = get_voting_table(voting_page)
    results = get_voting_results(clean_table(page))
    return results

# %%
url_all_statutes = 'https://www.sejm.gov.pl/Sejm9.nsf/agent.xsp?symbol=USTAWYALL&NrKadencji=9&NrPosiedzenia=28'
all_statutes = requests.get(url_all_statutes).text
urls = re.findall(REGEX_STATUTE, all_statutes)

# %%
raw_results = {}

# %%
i = 1

for url in urls:
    try:
        statute = URL_PATTERN.format(url)
        print("Getting {}: {}...".format(i, statute))
        i += 1
        voting_page = get_voting_page(statute)
        print("Sleeping...")
        sleep(1.2)
        results = get_voting_page_results(voting_page)
        raw_results[url] = results
    except:
        print("ERROR {}".format(url))
    sleep(0.5)
# Out:
# Getting 1: https://www.sejm.gov.pl/Sejm9.nsf/PrzebiegProc.xsp?nr=867...
# Sleeping...
# Getting 2: https://www.sejm.gov.pl/Sejm9.nsf/PrzebiegProc.xsp?nr=899...
# Sleeping...
# Getting 3: https://www.sejm.gov.pl/Sejm9.nsf/PrzebiegProc.xsp?nr=916...
# Sleeping...
# Getting 4: https://www.sejm.gov.pl/Sejm9.nsf/PrzebiegProc.xsp?nr=957...
# Sleeping...
# Getting 5: https://www.sejm.gov.pl/Sejm9.nsf/PrzebiegProc.xsp?nr=985...
# Sleeping...
# Getting 6: https://www.sejm.gov.pl/Sejm9.nsf/PrzebiegProc.xsp?nr=990...
# Sleeping...
# Getting 7: https://www.sejm.gov.pl/Sejm9.nsf/PrzebiegProc.xsp?nr=1016...
# Sleeping...
# Getting 8: https://www.sejm.gov.pl/Sejm9.nsf/PrzebiegProc.xsp?nr=808...
# Sleeping...
# Getting 9: https://www.sejm.gov.pl/Sejm9.nsf/PrzebiegProc.xsp?nr=969...
# Sleeping...
# Getting 10: https://www.sejm.gov.pl/Sejm9.nsf/PrzebiegProc.xsp?nr=970...
# Sleeping...
# Getting 11: https://www.sejm.gov.pl/Sejm9.nsf/PrzebiegProc.xsp?nr=1008...
# Sleeping...
# Getting 12: https://www.sejm.gov.pl/Sejm9.nsf/PrzebiegProc.xsp?nr=1012...
# Sleeping...
# Getting 13: https://www.sejm.gov.pl/Sejm9.nsf/PrzebiegProc.xsp?nr=1031...
# Sleeping...
# Getting 14: https://www.sejm.gov.pl/Sejm9.nsf/PrzebiegProc.xsp?nr=1033...
# Sleeping...
# Getting 15: https://www.sejm.gov.pl/Sejm9.nsf/PrzebiegProc.xsp?nr=1062...
# Sleeping...
# Getting 16: https://www.sejm.gov.pl/Sejm9.nsf/PrzebiegProc.xsp?nr=1068...
# Sleeping...
# Getting 17: https://www.sejm.gov.pl/Sejm9.nsf/PrzebiegProc.xsp?nr=1071...
# Sleeping...
# Getting 18: https://www.sejm.gov.pl/Sejm9.nsf/PrzebiegProc.xsp?nr=1072...
# Sleeping...
# Getting 19: https://www.sejm.gov.pl/Sejm9.nsf/PrzebiegProc.xsp?nr=1073...
# Sleeping...
# Getting 20: https://www.sejm.gov.pl/Sejm9.nsf/PrzebiegProc.xsp?nr=1009...
# Sleeping...
# Getting 21: https://www.sejm.gov.pl/Sejm9.nsf/PrzebiegProc.xsp?nr=578...
# Sleeping...
# Getting 22: https://www.sejm.gov.pl/Sejm9.nsf/PrzebiegProc.xsp?nr=833...
# Sleeping...
# Getting 23: https://www.sejm.gov.pl/Sejm9.nsf/PrzebiegProc.xsp?nr=860...
# Sleeping...
# Getting 24: https://www.sejm.gov.pl/Sejm9.nsf/PrzebiegProc.xsp?nr=909...
# Sleeping...
# Getting 25: https://www.sejm.gov.pl/Sejm9.nsf/PrzebiegProc.xsp?nr=911...
# Sleeping...
# Getting 26: https://www.sejm.gov.pl/Sejm9.nsf/PrzebiegProc.xsp?nr=913...
# Sleeping...
# Getting 27: https://www.sejm.gov.pl/Sejm9.nsf/PrzebiegProc.xsp?nr=933...
# Sleeping...
# Getting 28: https://www.sejm.gov.pl/Sejm9.nsf/PrzebiegProc.xsp?nr=935...
# Sleeping...
# Getting 29: https://www.sejm.gov.pl/Sejm9.nsf/PrzebiegProc.xsp?nr=939...
# Sleeping...
# Getting 30: https://www.sejm.gov.pl/Sejm9.nsf/PrzebiegProc.xsp?nr=464...
# Sleeping...
# Getting 31: https://www.sejm.gov.pl/Sejm9.nsf/PrzebiegProc.xsp?nr=986...
# Sleeping...
# Getting 32: https://www.sejm.gov.pl/Sejm9.nsf/PrzebiegProc.xsp?nr=1003...
# Sleeping...
# Getting 33: https://www.sejm.gov.pl/Sejm9.nsf/PrzebiegProc.xsp?nr=1004...
# Sleeping...
# Getting 34: https://www.sejm.gov.pl/Sejm9.nsf/PrzebiegProc.xsp?nr=48...
# Sleeping...
# Getting 35: https://www.sejm.gov.pl/Sejm9.nsf/PrzebiegProc.xsp?nr=859...
# Sleeping...
# Getting 36: https://www.sejm.gov.pl/Sejm9.nsf/PrzebiegProc.xsp?nr=908...
# Sleeping...
# Getting 37: https://www.sejm.gov.pl/Sejm9.nsf/PrzebiegProc.xsp?nr=917...
# Sleeping...
# Getting 38: https://www.sejm.gov.pl/Sejm9.nsf/PrzebiegProc.xsp?nr=932...
# Sleeping...
# Getting 39: https://www.sejm.gov.pl/Sejm9.nsf/PrzebiegProc.xsp?nr=280...
# Sleeping...
# Getting 40: https://www.sejm.gov.pl/Sejm9.nsf/PrzebiegProc.xsp?nr=687...
# Sleeping...
# Getting 41: https://www.sejm.gov.pl/Sejm9.nsf/PrzebiegProc.xsp?nr=764...
# Sleeping...
# Getting 42: https://www.sejm.gov.pl/Sejm9.nsf/PrzebiegProc.xsp?nr=801...
# Sleeping...
# Getting 43: https://www.sejm.gov.pl/Sejm9.nsf/PrzebiegProc.xsp?nr=828...
# Sleeping...
# Getting 44: https://www.sejm.gov.pl/Sejm9.nsf/PrzebiegProc.xsp?nr=858...
# Sleeping...
# Getting 45: https://www.sejm.gov.pl/Sejm9.nsf/PrzebiegProc.xsp?nr=868...
# Sleeping...
# Getting 46: https://www.sejm.gov.pl/Sejm9.nsf/PrzebiegProc.xsp?nr=877...
# Sleeping...
# Getting 47: https://www.sejm.gov.pl/Sejm9.nsf/PrzebiegProc.xsp?nr=640...
# Sleeping...
# Getting 48: https://www.sejm.gov.pl/Sejm9.nsf/PrzebiegProc.xsp?nr=822...
# Sleeping...
# Getting 49: https://www.sejm.gov.pl/Sejm9.nsf/PrzebiegProc.xsp?nr=719...
# Sleeping...
# Getting 50: https://www.sejm.gov.pl/Sejm9.nsf/PrzebiegProc.xsp?nr=723...
# Sleeping...
# Getting 51: https://www.sejm.gov.pl/Sejm9.nsf/PrzebiegProc.xsp?nr=809...
# Sleeping...
# Getting 52: https://www.sejm.gov.pl/Sejm9.nsf/PrzebiegProc.xsp?nr=829...
# Sleeping...
# Getting 53: https://www.sejm.gov.pl/Sejm9.nsf/PrzebiegProc.xsp?nr=732...
# Sleeping...
# Getting 54: https://www.sejm.gov.pl/Sejm9.nsf/PrzebiegProc.xsp?nr=766...
# Sleeping...
# Getting 55: https://www.sejm.gov.pl/Sejm9.nsf/PrzebiegProc.xsp?nr=831...
# Sleeping...
# Getting 56: https://www.sejm.gov.pl/Sejm9.nsf/PrzebiegProc.xsp?nr=209...
# Sleeping...
# Getting 57: https://www.sejm.gov.pl/Sejm9.nsf/PrzebiegProc.xsp?nr=238...
# Sleeping...
# Getting 58: https://www.sejm.gov.pl/Sejm9.nsf/PrzebiegProc.xsp?nr=240...
# Sleeping...
# Getting 59: https://www.sejm.gov.pl/Sejm9.nsf/PrzebiegProc.xsp?nr=512...
# Sleeping...
# Getting 60: https://www.sejm.gov.pl/Sejm9.nsf/PrzebiegProc.xsp?nr=534...
# Sleeping...
# Getting 61: https://www.sejm.gov.pl/Sejm9.nsf/PrzebiegProc.xsp?nr=563...
# Sleeping...
# Getting 62: https://www.sejm.gov.pl/Sejm9.nsf/PrzebiegProc.xsp?nr=608...
# Sleeping...
# Getting 63: https://www.sejm.gov.pl/Sejm9.nsf/PrzebiegProc.xsp?nr=644...
# Sleeping...
# Getting 64: https://www.sejm.gov.pl/Sejm9.nsf/PrzebiegProc.xsp?nr=680...
# Sleeping...
# Getting 65: https://www.sejm.gov.pl/Sejm9.nsf/PrzebiegProc.xsp?nr=688...
# Sleeping...
# Getting 66: https://www.sejm.gov.pl/Sejm9.nsf/PrzebiegProc.xsp?nr=720...
# Sleeping...
# Getting 67: https://www.sejm.gov.pl/Sejm9.nsf/PrzebiegProc.xsp?nr=798...
# Sleeping...
# Getting 68: https://www.sejm.gov.pl/Sejm9.nsf/PrzebiegProc.xsp?nr=799...
# Sleeping...
# Getting 69: https://www.sejm.gov.pl/Sejm9.nsf/PrzebiegProc.xsp?nr=704...
# ERROR PrzebiegProc.xsp?nr=704
# Getting 70: https://www.sejm.gov.pl/Sejm9.nsf/PrzebiegProc.xsp?nr=642...
# Sleeping...
# Getting 71: https://www.sejm.gov.pl/Sejm9.nsf/PrzebiegProc.xsp?nr=643...
# Sleeping...
# Getting 72: https://www.sejm.gov.pl/Sejm9.nsf/PrzebiegProc.xsp?nr=645...
# Sleeping...
# Getting 73: https://www.sejm.gov.pl/Sejm9.nsf/PrzebiegProc.xsp?nr=678...
# Sleeping...
# Getting 74: https://www.sejm.gov.pl/Sejm9.nsf/PrzebiegProc.xsp?nr=718...
# Sleeping...
# Getting 75: https://www.sejm.gov.pl/Sejm9.nsf/PrzebiegProc.xsp?nr=722...
# Sleeping...
# Getting 76: https://www.sejm.gov.pl/Sejm9.nsf/PrzebiegProc.xsp?nr=761...
# Sleeping...
# Getting 77: https://www.sejm.gov.pl/Sejm9.nsf/PrzebiegProc.xsp?nr=762...
# Sleeping...
# Getting 78: https://www.sejm.gov.pl/Sejm9.nsf/PrzebiegProc.xsp?nr=763...
# Sleeping...
# Getting 79: https://www.sejm.gov.pl/Sejm9.nsf/PrzebiegProc.xsp?nr=765...
# Sleeping...
# Getting 80: https://www.sejm.gov.pl/Sejm9.nsf/PrzebiegProc.xsp?nr=768...
# Sleeping...
# Getting 81: https://www.sejm.gov.pl/Sejm9.nsf/PrzebiegProc.xsp?nr=772...
# Sleeping...
# Getting 82: https://www.sejm.gov.pl/Sejm9.nsf/PrzebiegProc.xsp?nr=738...
# Sleeping...
# Getting 83: https://www.sejm.gov.pl/Sejm9.nsf/PrzebiegProc.xsp?nr=641...
# Sleeping...
# Getting 84: https://www.sejm.gov.pl/Sejm9.nsf/PrzebiegProc.xsp?nr=679...
# Sleeping...
# Getting 85: https://www.sejm.gov.pl/Sejm9.nsf/PrzebiegProc.xsp?nr=733...
# Sleeping...
# Getting 86: https://www.sejm.gov.pl/Sejm9.nsf/PrzebiegProc.xsp?nr=734...
# Sleeping...
# Getting 87: https://www.sejm.gov.pl/Sejm9.nsf/PrzebiegProc.xsp?nr=735...
# Sleeping...
# Getting 88: https://www.sejm.gov.pl/Sejm9.nsf/PrzebiegProc.xsp?nr=239...
# Sleeping...
# Getting 89: https://www.sejm.gov.pl/Sejm9.nsf/PrzebiegProc.xsp?nr=484...
# Sleeping...
# Getting 90: https://www.sejm.gov.pl/Sejm9.nsf/PrzebiegProc.xsp?nr=572...
# Sleeping...
# Getting 91: https://www.sejm.gov.pl/Sejm9.nsf/PrzebiegProc.xsp?nr=574...
# Sleeping...
# Getting 92: https://www.sejm.gov.pl/Sejm9.nsf/PrzebiegProc.xsp?nr=683...
# Sleeping...
# Getting 93: https://www.sejm.gov.pl/Sejm9.nsf/PrzebiegProc.xsp?nr=717...
# Sleeping...
# Getting 94: https://www.sejm.gov.pl/Sejm9.nsf/PrzebiegProc.xsp?nr=459...
# Sleeping...
# Getting 95: https://www.sejm.gov.pl/Sejm9.nsf/PrzebiegProc.xsp?nr=460...
# Sleeping...
# Getting 96: https://www.sejm.gov.pl/Sejm9.nsf/PrzebiegProc.xsp?nr=487...
# Sleeping...
# Getting 97: https://www.sejm.gov.pl/Sejm9.nsf/PrzebiegProc.xsp?nr=520...
# Sleeping...
# Getting 98: https://www.sejm.gov.pl/Sejm9.nsf/PrzebiegProc.xsp?nr=457...
# Sleeping...
# Getting 99: https://www.sejm.gov.pl/Sejm9.nsf/PrzebiegProc.xsp?nr=590...
# Sleeping...
# Getting 100: https://www.sejm.gov.pl/Sejm9.nsf/PrzebiegProc.xsp?nr=378...
# Sleeping...
# Getting 101: https://www.sejm.gov.pl/Sejm9.nsf/PrzebiegProc.xsp?nr=133...
# Sleeping...
# Getting 102: https://www.sejm.gov.pl/Sejm9.nsf/PrzebiegProc.xsp?nr=260...
# Sleeping...
# Getting 103: https://www.sejm.gov.pl/Sejm9.nsf/PrzebiegProc.xsp?nr=420...
# Sleeping...
# Getting 104: https://www.sejm.gov.pl/Sejm9.nsf/PrzebiegProc.xsp?nr=559...
# Sleeping...
# Getting 105: https://www.sejm.gov.pl/Sejm9.nsf/PrzebiegProc.xsp?nr=562...
# Sleeping...
# Getting 106: https://www.sejm.gov.pl/Sejm9.nsf/PrzebiegProc.xsp?nr=573...
# Sleeping...
# Getting 107: https://www.sejm.gov.pl/Sejm9.nsf/PrzebiegProc.xsp?nr=605...
# Sleeping...
# Getting 108: https://www.sejm.gov.pl/Sejm9.nsf/PrzebiegProc.xsp?nr=388...
# Sleeping...
# Getting 109: https://www.sejm.gov.pl/Sejm9.nsf/PrzebiegProc.xsp?nr=432...
# Sleeping...
# Getting 110: https://www.sejm.gov.pl/Sejm9.nsf/PrzebiegProc.xsp?nr=437...
# Sleeping...
# Getting 111: https://www.sejm.gov.pl/Sejm9.nsf/PrzebiegProc.xsp?nr=452...
# Sleeping...
# Getting 112: https://www.sejm.gov.pl/Sejm9.nsf/PrzebiegProc.xsp?nr=483...
# Sleeping...
# Getting 113: https://www.sejm.gov.pl/Sejm9.nsf/PrzebiegProc.xsp?nr=495...
# Sleeping...
# Getting 114: https://www.sejm.gov.pl/Sejm9.nsf/PrzebiegProc.xsp?nr=515...
# Sleeping...
# Getting 115: https://www.sejm.gov.pl/Sejm9.nsf/PrzebiegProc.xsp?nr=535...
# Sleeping...
# Getting 116: https://www.sejm.gov.pl/Sejm9.nsf/PrzebiegProc.xsp?nr=550...
# Sleeping...
# Getting 117: https://www.sejm.gov.pl/Sejm9.nsf/PrzebiegProc.xsp?nr=551...
# Sleeping...
# Getting 118: https://www.sejm.gov.pl/Sejm9.nsf/PrzebiegProc.xsp?nr=400...
# Sleeping...
# Getting 119: https://www.sejm.gov.pl/Sejm9.nsf/PrzebiegProc.xsp?nr=430...
# Sleeping...
# Getting 120: https://www.sejm.gov.pl/Sejm9.nsf/PrzebiegProc.xsp?nr=433...
# Sleeping...
# Getting 121: https://www.sejm.gov.pl/Sejm9.nsf/PrzebiegProc.xsp?nr=514...
# Sleeping...
# Getting 122: https://www.sejm.gov.pl/Sejm9.nsf/PrzebiegProc.xsp?nr=172...
# Sleeping...
# Getting 123: https://www.sejm.gov.pl/Sejm9.nsf/PrzebiegProc.xsp?nr=300...
# Sleeping...
# Getting 124: https://www.sejm.gov.pl/Sejm9.nsf/PrzebiegProc.xsp?nr=431...
# Sleeping...
# Getting 125: https://www.sejm.gov.pl/Sejm9.nsf/PrzebiegProc.xsp?nr=455...
# Sleeping...
# Getting 126: https://www.sejm.gov.pl/Sejm9.nsf/PrzebiegProc.xsp?nr=64...
# Sleeping...
# Getting 127: https://www.sejm.gov.pl/Sejm9.nsf/PrzebiegProc.xsp?nr=268...
# Sleeping...
# Getting 128: https://www.sejm.gov.pl/Sejm9.nsf/PrzebiegProc.xsp?nr=415...
# Sleeping...
# Getting 129: https://www.sejm.gov.pl/Sejm9.nsf/PrzebiegProc.xsp?nr=422...
# Sleeping...
# Getting 130: https://www.sejm.gov.pl/Sejm9.nsf/PrzebiegProc.xsp?nr=283...
# Sleeping...
# Getting 131: https://www.sejm.gov.pl/Sejm9.nsf/PrzebiegProc.xsp?nr=382...
# Sleeping...
# Getting 132: https://www.sejm.gov.pl/Sejm9.nsf/PrzebiegProc.xsp?nr=406...
# Sleeping...
# Getting 133: https://www.sejm.gov.pl/Sejm9.nsf/PrzebiegProc.xsp?nr=207...
# Sleeping...
# Getting 134: https://www.sejm.gov.pl/Sejm9.nsf/PrzebiegProc.xsp?nr=368...
# Sleeping...
# Getting 135: https://www.sejm.gov.pl/Sejm9.nsf/PrzebiegProc.xsp?nr=208...
# Sleeping...
# Getting 136: https://www.sejm.gov.pl/Sejm9.nsf/PrzebiegProc.xsp?nr=281...
# Sleeping...
# Getting 137: https://www.sejm.gov.pl/Sejm9.nsf/PrzebiegProc.xsp?nr=334...
# Sleeping...
# Getting 138: https://www.sejm.gov.pl/Sejm9.nsf/PrzebiegProc.xsp?nr=383...
# Sleeping...
# Getting 139: https://www.sejm.gov.pl/Sejm9.nsf/PrzebiegProc.xsp?nr=199...
# Sleeping...
# Getting 140: https://www.sejm.gov.pl/Sejm9.nsf/PrzebiegProc.xsp?nr=200...
# Sleeping...
# Getting 141: https://www.sejm.gov.pl/Sejm9.nsf/PrzebiegProc.xsp?nr=305...
# Sleeping...
# Getting 142: https://www.sejm.gov.pl/Sejm9.nsf/PrzebiegProc.xsp?nr=336...
# Sleeping...
# Getting 143: https://www.sejm.gov.pl/Sejm9.nsf/PrzebiegProc.xsp?nr=344...
# Sleeping...
# Getting 144: https://www.sejm.gov.pl/Sejm9.nsf/PrzebiegProc.xsp?nr=346...
# Sleeping...
# Getting 145: https://www.sejm.gov.pl/Sejm9.nsf/PrzebiegProc.xsp?nr=261...
# Sleeping...
# Getting 146: https://www.sejm.gov.pl/Sejm9.nsf/PrzebiegProc.xsp?nr=335...
# Sleeping...
# Getting 147: https://www.sejm.gov.pl/Sejm9.nsf/PrzebiegProc.xsp?nr=342...
# Sleeping...
# Getting 148: https://www.sejm.gov.pl/Sejm9.nsf/PrzebiegProc.xsp?nr=269...
# Sleeping...
# Getting 149: https://www.sejm.gov.pl/Sejm9.nsf/PrzebiegProc.xsp?nr=279...
# Sleeping...
# Getting 150: https://www.sejm.gov.pl/Sejm9.nsf/PrzebiegProc.xsp?nr=130...
# Sleeping...
# Getting 151: https://www.sejm.gov.pl/Sejm9.nsf/PrzebiegProc.xsp?nr=202...
# Sleeping...
# Getting 152: https://www.sejm.gov.pl/Sejm9.nsf/PrzebiegProc.xsp?nr=324...
# Sleeping...
# Getting 153: https://www.sejm.gov.pl/Sejm9.nsf/PrzebiegProc.xsp?nr=328...
# Sleeping...
# Getting 154: https://www.sejm.gov.pl/Sejm9.nsf/PrzebiegProc.xsp?nr=313...
# Sleeping...
# Getting 155: https://www.sejm.gov.pl/Sejm9.nsf/PrzebiegProc.xsp?nr=299...
# Sleeping...
# Getting 156: https://www.sejm.gov.pl/Sejm9.nsf/PrzebiegProc.xsp?nr=301...
# Sleeping...
# Getting 157: https://www.sejm.gov.pl/Sejm9.nsf/PrzebiegProc.xsp?nr=302...
# Sleeping...
# Getting 158: https://www.sejm.gov.pl/Sejm9.nsf/PrzebiegProc.xsp?nr=265...
# Sleeping...
# Getting 159: https://www.sejm.gov.pl/Sejm9.nsf/PrzebiegProc.xsp?nr=112...
# Sleeping...
# Getting 160: https://www.sejm.gov.pl/Sejm9.nsf/PrzebiegProc.xsp?nr=210...
# Sleeping...
# Getting 161: https://www.sejm.gov.pl/Sejm9.nsf/PrzebiegProc.xsp?nr=45...
# Sleeping...
# Getting 162: https://www.sejm.gov.pl/Sejm9.nsf/PrzebiegProc.xsp?nr=62...
# Sleeping...
# Getting 163: https://www.sejm.gov.pl/Sejm9.nsf/PrzebiegProc.xsp?nr=63...
# Sleeping...
# Getting 164: https://www.sejm.gov.pl/Sejm9.nsf/PrzebiegProc.xsp?nr=113...
# Sleeping...
# Getting 165: https://www.sejm.gov.pl/Sejm9.nsf/PrzebiegProc.xsp?nr=114...
# Sleeping...
# Getting 166: https://www.sejm.gov.pl/Sejm9.nsf/PrzebiegProc.xsp?nr=121...
# Sleeping...
# Getting 167: https://www.sejm.gov.pl/Sejm9.nsf/PrzebiegProc.xsp?nr=171...
# Sleeping...
# Getting 168: https://www.sejm.gov.pl/Sejm9.nsf/PrzebiegProc.xsp?nr=46...
# Sleeping...
# Getting 169: https://www.sejm.gov.pl/Sejm9.nsf/PrzebiegProc.xsp?nr=65...
# Sleeping...
# Getting 170: https://www.sejm.gov.pl/Sejm9.nsf/PrzebiegProc.xsp?nr=119...
# Sleeping...
# Getting 171: https://www.sejm.gov.pl/Sejm9.nsf/PrzebiegProc.xsp?nr=128...
# Sleeping...
# Getting 172: https://www.sejm.gov.pl/Sejm9.nsf/PrzebiegProc.xsp?nr=155...
# Sleeping...
# Getting 173: https://www.sejm.gov.pl/Sejm9.nsf/PrzebiegProc.xsp?nr=158...
# Sleeping...
# Getting 174: https://www.sejm.gov.pl/Sejm9.nsf/PrzebiegProc.xsp?nr=159...
# Sleeping...
# Getting 175: https://www.sejm.gov.pl/Sejm9.nsf/PrzebiegProc.xsp?nr=43...
# Sleeping...
# Getting 176: https://www.sejm.gov.pl/Sejm9.nsf/PrzebiegProc.xsp?nr=89...
# Sleeping...
# Getting 177: https://www.sejm.gov.pl/Sejm9.nsf/PrzebiegProc.xsp?nr=97...
# Sleeping...
# Getting 178: https://www.sejm.gov.pl/Sejm9.nsf/PrzebiegProc.xsp?nr=115...
# Sleeping...
# Getting 179: https://www.sejm.gov.pl/Sejm9.nsf/PrzebiegProc.xsp?nr=116...
# Sleeping...
# Getting 180: https://www.sejm.gov.pl/Sejm9.nsf/PrzebiegProc.xsp?nr=117...
# Sleeping...
# Getting 181: https://www.sejm.gov.pl/Sejm9.nsf/PrzebiegProc.xsp?nr=118...
# Sleeping...
# Getting 182: https://www.sejm.gov.pl/Sejm9.nsf/PrzebiegProc.xsp?nr=13...
# Sleeping...
# Getting 183: https://www.sejm.gov.pl/Sejm9.nsf/PrzebiegProc.xsp?nr=56...
# Sleeping...
# Getting 184: https://www.sejm.gov.pl/Sejm9.nsf/PrzebiegProc.xsp?nr=68...
# Sleeping...
# Getting 185: https://www.sejm.gov.pl/Sejm9.nsf/PrzebiegProc.xsp?nr=69...
# Sleeping...
# Getting 186: https://www.sejm.gov.pl/Sejm9.nsf/PrzebiegProc.xsp?nr=87...
# Sleeping...
# Getting 187: https://www.sejm.gov.pl/Sejm9.nsf/PrzebiegProc.xsp?nr=40...
# Sleeping...
# Getting 188: https://www.sejm.gov.pl/Sejm9.nsf/PrzebiegProc.xsp?nr=41...
# Sleeping...
# Getting 189: https://www.sejm.gov.pl/Sejm9.nsf/PrzebiegProc.xsp?nr=44...
# Sleeping...
# Getting 190: https://www.sejm.gov.pl/Sejm9.nsf/PrzebiegProc.xsp?nr=51...
# Sleeping...
# Getting 191: https://www.sejm.gov.pl/Sejm9.nsf/PrzebiegProc.xsp?nr=15...
# Sleeping...

# %%
all_tables_for_against = []

for statute in list(raw_results.values()):
    tabled = get_table_for_against(statute)
    all_tables_for_against.append(tabled)

# %%
co_voters = []
PiS_co_voters = defaultdict(int)

for table in all_tables_for_against:
    co_voters = []
    expected = table['PiS']
    for party in table:
        if party != 'PiS' and table[party] == expected:
            co_voters.append(party)
    for party in co_voters:
        PiS_co_voters[party] += 1

# %%
co_voters = []
KO_co_voters = defaultdict(int)

for table in all_tables_for_against:
    co_voters = []
    expected = table['KO']
    for party in table:
        if party != 'KO' and table[party] == expected:
            co_voters.append(party)
    for party in co_voters:
        KO_co_voters[party] += 1

# %%
vote_participation = defaultdict(int)
for table in all_tables_for_against:
    for party in table:
        vote_participation[party] += 1

# %%
print(vote_participation)
# Out:
# defaultdict(<class 'int'>, {'PiS': 190, 'KO': 190, 'Lewica': 190, 'KP': 60, 'Konfederacja': 190, 'Kukiz15': 37, 'niez.': 190, 'Polska2050': 37, 'PSL-Kukiz15': 130})

# %%
print(PiS_co_voters)
# Out:
# defaultdict(<class 'int'>, {'KO': 129, 'Lewica': 138, 'KP': 46, 'Kukiz15': 22, 'Polska2050': 25, 'niez.': 130, 'Konfederacja': 61, 'PSL-Kukiz15': 90})

# %%
print(KO_co_voters)
# Out:
# defaultdict(<class 'int'>, {'Lewica': 171, 'KP': 50, 'Konfederacja': 98, 'Kukiz15': 26, 'niez.': 165, 'Polska2050': 35, 'PiS': 129, 'PSL-Kukiz15': 107})

# %%
pattern = "Posłowie i posłanki z {} (jako klub/koło/zbiorowość) głosowali tak samo, jak {} w {:.2f}% swoich głosowań."


for other_party in ('PiS', 'KO'):
    for party in vote_participation:
        if party != other_party:
            num = PiS_co_voters if other_party == 'PiS' else KO_co_voters
            den = vote_participation
            percent = num[party] / den[party] * 100
            print(pattern.format(party, other_party, percent))
    print('-' * 100)
# Out:
# Posłowie i posłanki z KO (jako klub/koło/zbiorowość) głosowali tak samo, jak PiS w 67.89% swoich głosowań.
# Posłowie i posłanki z Lewica (jako klub/koło/zbiorowość) głosowali tak samo, jak PiS w 72.63% swoich głosowań.
# Posłowie i posłanki z KP (jako klub/koło/zbiorowość) głosowali tak samo, jak PiS w 76.67% swoich głosowań.
# Posłowie i posłanki z Konfederacja (jako klub/koło/zbiorowość) głosowali tak samo, jak PiS w 32.11% swoich głosowań.
# Posłowie i posłanki z Kukiz15 (jako klub/koło/zbiorowość) głosowali tak samo, jak PiS w 59.46% swoich głosowań.
# Posłowie i posłanki z niez. (jako klub/koło/zbiorowość) głosowali tak samo, jak PiS w 68.42% swoich głosowań.
# Posłowie i posłanki z Polska2050 (jako klub/koło/zbiorowość) głosowali tak samo, jak PiS w 67.57% swoich głosowań.
# Posłowie i posłanki z PSL-Kukiz15 (jako klub/koło/zbiorowość) głosowali tak samo, jak PiS w 69.23% swoich głosowań.
# ----------------------------------------------------------------------------------------------------
# Posłowie i posłanki z PiS (jako klub/koło/zbiorowość) głosowali tak samo, jak KO w 67.89% swoich głosowań.
# Posłowie i posłanki z Lewica (jako klub/koło/zbiorowość) głosowali tak samo, jak KO w 90.00% swoich głosowań.
# Posłowie i posłanki z KP (jako klub/koło/zbiorowość) głosowali tak samo, jak KO w 83.33% swoich głosowań.
# Posłowie i posłanki z Konfederacja (jako klub/koło/zbiorowość) głosowali tak samo, jak KO w 51.58% swoich głosowań.
# Posłowie i posłanki z Kukiz15 (jako klub/koło/zbiorowość) głosowali tak samo, jak KO w 70.27% swoich głosowań.
# Posłowie i posłanki z niez. (jako klub/koło/zbiorowość) głosowali tak samo, jak KO w 86.84% swoich głosowań.
# Posłowie i posłanki z Polska2050 (jako klub/koło/zbiorowość) głosowali tak samo, jak KO w 94.59% swoich głosowań.
# Posłowie i posłanki z PSL-Kukiz15 (jako klub/koło/zbiorowość) głosowali tak samo, jak KO w 82.31% swoich głosowań.
# ----------------------------------------------------------------------------------------------------
