# %%
from collections import defaultdict
from time import sleep
import os
import re
import requests
import random
from tika import parser

# %%
def get_draft_urls(sejm_url = ""):
    all_statutes = requests.get(sejm_url)
    pattern = r"Sejm\d.nsf/PrzebiegProc.xsp\?nr=\d+"
    urls = re.findall(pattern,all_statutes.text)
    print("Extracted all statute URLs")
    return urls

# %%
urls = get_draft_urls("http://www.sejm.gov.pl/sejm8.nsf/agent.xsp?symbol=USTAWYALL&NrKadencji=8&NrPosiedzenia=86")

# %%
def filter_draft_urls(draft_urls):
    filtered_urls = {"poselski": [], "rzadowy": [], "obywatelski": [], "prezydencki": [], "senacki": [], "komisyjny": []}
    print("Filtering {} URLs...".format(len(draft_urls)))
    i = 0
    for url in draft_urls:
        url = "http://www.sejm.gov.pl/" + url
        sleep_time = 1 + 2 * random.random()
        sleep(sleep_time)
        i += 1
        if i % 10 == 0:
            print("#")
        if i % 100 == 0: 
            print("Done with {} of {} URLs...".format(i, len(draft_urls)))
        page = requests.get(url).text
        if page and page.find("Poselski projekt ustawy") > -1:
            filtered_urls["poselski"].append(url)
        elif page and page.find("Rządowy projekt ustawy") > -1:
            filtered_urls["rzadowy"].append(url)
        elif page and page.find("Obywatelski projekt ustawy") > -1:
            filtered_urls["obywatelski"].append(url)
        elif page and page.find("Przedstawiony przez Prezydenta") > -1:
            filtered_urls["prezydencki"].append(url)
        elif page and page.find("Senacki projekt ustawy") > -1:
            filtered_urls["senacki"].append(url)
        elif page and page.find("Komisyjny projekt ustawy") > -1:
            filtered_urls["komisyjny"].append(url)    
        
    return filtered_urls

# %%
categories = filter_draft_urls(urls)
# Out:
# Filtering 923 URLs...
# #
# #
# #
# #
# #
# #
# #
# #
# #
# #
# Done with 100 of 923 URLs...
# #
# #
# #
# #
# #
# #
# #
# #
# #
# #
# Done with 200 of 923 URLs...
# #
# #
# #
# #
# #
# #
# #
# #
# #
# #
# Done with 300 of 923 URLs...
# #
# #
# #
# #
# #
# #
# #
# #
# #
# #
# Done with 400 of 923 URLs...
# #
# #
# #
# #
# #
# #
# #
# #
# #
# #
# Done with 500 of 923 URLs...
# #
# #
# #
# #
# #
# #
# #
# #
# #
# #
# Done with 600 of 923 URLs...
# #
# #
# #
# #
# #
# #
# #
# #
# #
# #
# Done with 700 of 923 URLs...
# #
# #
# #
# #
# #
# #
# #
# #
# #
# #
# Done with 800 of 923 URLs...
# #
# #
# #
# #
# #
# #
# #
# #
# #
# #
# Done with 900 of 923 URLs...
# #
# #

# %%
print("Poselskie: {}".format(len(categories["poselski"])))
print("Rzadowe: {}".format(len(categories["rzadowy"])))
print("Prezydenckie: {}".format(len(categories["prezydencki"])))
print("Komisyjne: {}".format(len(categories["komisyjny"])))
print("Senackie: {}".format(len(categories["senacki"])))
# Out:
# Poselskie: 180
# Rzadowe: 657
# Prezydenckie: 26
# Komisyjne: 25
# Senackie: 33

# %%
def get_pdf_url(draft_url, term = "8"):
    draft_no = draft_url[draft_url.find("=")+1:]
    source_url = "http://www.sejm.gov.pl/Sejm{}.nsf/druk.xsp?nr={}".format(term, draft_no)
    source = requests.get(source_url)
    filename = "/{}.pdf".format(draft_no)
    resource_pattern = r"http.+" + filename
    resource_url = re.findall(resource_pattern, source.text)
    return resource_url[0]

# %%
urls_poselskie = []
for url in categories["poselski"]:
    sleep(random.random())
    try:
        urls_poselskie.append(get_pdf_url(url))
    except:
        print("Failed to append: {}".format(url))
# Out:
# Failed to append: http://www.sejm.gov.pl/Sejm8.nsf/PrzebiegProc.xsp?nr=106
# Failed to append: http://www.sejm.gov.pl/Sejm8.nsf/PrzebiegProc.xsp?nr=10
# Failed to append: http://www.sejm.gov.pl/Sejm8.nsf/PrzebiegProc.xsp?nr=12

# %%
urls_poselskie = urls_poselskie + ["http://orka.sejm.gov.pl/Druki8ka.nsf/0/2BDD3075AA4884F1C1257F1B003546CE/%24File/druk%20nr%20106.pdf",
                                  "http://orka.sejm.gov.pl/Druki8ka.nsf/0/683F6A51545668D3C1257EFF005D501A/%24File/druk%20nr%2010.pdf",
                                  "http://orka.sejm.gov.pl/Druki8ka.nsf/0/0527EC5BED627495C1257F0000473007/%24File/druk%20nr%2012.pdf"]

# %%
def download_pdf(url):
    local_filename = "dst/" + url.split('/')[-1]
    r = requests.get(url)
    sleep(1)
    f = open(local_filename, 'wb')
    for chunk in r.iter_content(chunk_size=512 * 1024): 
        if chunk: # filter out keep-alive new chunks
            f.write(chunk)
    f.close()
    return local_filename

# %%
for url in url_poselskie:
    download_pdf(url)

# %%
### Change this to your local path.

os.chdir("D:/ustawy")

# %%
### We need to parse the PDFs locally. Tika seems to be the most accurate available tool.

def extract_sponsors(draft_pdf):
    _to_remove = (";", "\n", "\t", ".", ",")
    draft = parser.from_file(draft_pdf)['content']
    start = draft.find("(-)")
    end = draft[start:].find(".") + start
    temp_sponsors = " ".join(draft[start:end].split())
    for c in _to_remove:
        temp_sponsors = temp_sponsors.replace(c, "")
    temp_sponsors = temp_sponsors.replace("(- )","(-)")
    temp_sponsors = temp_sponsors.replace("(-)", ";")[1:].split(";")
    sponsors = [s.strip() for s in temp_sponsors]
    return sponsors

# %%
def calculate_stats(dir = ""):
    i = 0
    bad_files = []
    sponsor_stats = defaultdict(int)
    for filename in os.listdir(os.curdir):
        i += 1
        try:    
            if filename.endswith(".pdf"): 
                sponsors = extract_sponsors(filename)
                for sponsor in sponsors:
                    sponsor_stats[sponsor] += 1
                print("{} OK.".format(filename), end = ' ')
            else:
                continue
        except Exception as e:
            print("\nBad file: {}".format(filename))
            print(e.args)
            bad_files.append(filename)
    print("{} files checked. {} bad files".format(i, len(bad_files)))
    return sponsor_stats, bad_files

# %%
good_stats, bad_stats = calculate_stats()
# Out:
# Bad file: 10.pdf
# ("'NoneType' object has no attribute 'find'",)
# 103.pdf OK. 1032.pdf OK. 104.pdf OK. 1044.pdf OK. 1047.pdf OK. 105.pdf OK. 1058.pdf OK. 1059.pdf OK.
# Bad file: 106.pdf
# ("'NoneType' object has no attribute 'find'",)
# 107.pdf OK. 1126.pdf OK. 1127.pdf OK. 1143.pdf OK. 1144.pdf OK. 115.pdf OK. 119.pdf OK.
# Bad file: 12.pdf
# ("'NoneType' object has no attribute 'find'",)
# 120.pdf OK. 121.pdf OK. 1213.pdf OK. 122.pdf OK. 1256.pdf OK. 1257.pdf OK. 1265.pdf OK. 1324.pdf OK. 1334.pdf OK. 134.pdf OK. 135.pdf OK. 136.pdf OK. 1364.pdf OK. 1412.pdf OK. 1456.pdf OK. 1491.pdf OK. 1495.pdf OK. 150.pdf OK. 1537.pdf OK. 154.pdf OK. 158.pdf OK. 162.pdf OK. 163.pdf OK. 1654.pdf OK. 1661.pdf OK. 1689.pdf OK. 171.pdf OK. 1727.pdf OK. 1733.pdf OK. 1750.pdf OK. 1849.pdf OK. 1904.pdf OK. 1919.pdf OK. 1970.pdf OK. 1977.pdf OK. 1988.pdf OK. 2001.pdf OK. 2008.pdf OK. 2033.pdf OK. 2084.pdf OK. 211.pdf OK. 2115.pdf OK. 212.pdf OK. 2131.pdf OK. 2160.pdf OK. 2183.pdf OK. 219.pdf OK. 22.pdf OK. 220.pdf OK. 2224.pdf OK. 2235.pdf OK. 2250.pdf OK. 2356.pdf OK. 2388.pdf OK. 2389.pdf OK. 2390.pdf OK. 2413.pdf OK. 2450.pdf OK. 2460.pdf OK. 2463.pdf OK. 2469.pdf OK. 2479.pdf OK. 2480.pdf OK. 2506.pdf OK. 2550.pdf OK. 2575.pdf OK. 258.pdf OK. 265.pdf OK. 2660.pdf OK. 2692.pdf OK. 2719.pdf OK. 2731.pdf OK. 274.pdf OK. 277.pdf OK. 2831.pdf OK. 2865.pdf OK. 289.pdf OK. 292.pdf OK. 2931.pdf OK. 2992.pdf OK. 3013.pdf OK. 3080.pdf OK. 3081.pdf OK. 3084.pdf OK. 3114.pdf OK. 312.pdf OK. 3123.pdf OK. 315.pdf OK. 3158.pdf OK. 3163.pdf OK. 3169.pdf OK. 32.pdf OK. 3206.pdf OK. 3217.pdf OK. 3270.pdf OK. 3271.pdf OK. 3272.pdf OK. 3312.pdf OK. 334.pdf OK. 3396.pdf OK. 3454.pdf OK. 3455.pdf OK. 3496.pdf OK. 3497.pdf OK. 3498.pdf OK. 3548.pdf OK. 356.pdf OK. 3615.pdf OK. 362.pdf OK. 364.pdf OK. 3662.pdf OK. 3689.pdf OK. 3813.pdf OK. 397.pdf OK. 427.pdf OK. 428.pdf OK. 429.pdf OK. 433.pdf OK. 451.pdf OK. 476.pdf OK. 49.pdf OK. 558.pdf OK. 561.pdf OK. 563.pdf OK. 564.pdf OK. 570.pdf OK. 572.pdf OK. 592.pdf OK. 627.pdf OK. 628.pdf OK. 642.pdf OK. 648.pdf OK. 653.pdf OK. 659.pdf OK. 670.pdf OK. 673.pdf OK. 679.pdf OK. 68.pdf OK. 71.pdf OK. 710.pdf OK. 715.pdf OK. 72.pdf OK. 73.pdf OK. 74.pdf OK. 75.pdf OK. 750.pdf OK. 76.pdf OK. 77.pdf OK. 771.pdf OK. 80.pdf OK.
# Bad file: 812.pdf
# ("'NoneType' object has no attribute 'find'",)
# 826.pdf OK. 827.pdf OK. 842.pdf OK. 850.pdf OK. 880.pdf OK. 889.pdf OK. 897.pdf OK. 908.pdf OK. 963.pdf OK. 969.pdf OK. 995.pdf OK. 180 files checked. 4 bad files

# %%
### List files for manual insertion.

print(bad_stats)
# Out:
# ['10.pdf', '106.pdf', '12.pdf', '812.pdf']

# %%
### Shallow copy for further work

stats = good_stats.copy()

# %%
stats["Andrzej Gawron"] += stats["Andrzej januszmarkiewicz Stamp Kryj"]
del stats["Andrzej januszmarkiewicz Stamp Kryj"]

# %%
stats["Anna Schmidt-Rodziewicz"] += stats["Anna Schmidt- Rodziewicz"]
del stats["Anna Schmidt- Rodziewicz"]
stats["Beata Mateusiak-Pielucha"] += stats["Beata Mateusiak- Pielucha"]
del stats["Beata Mateusiak- Pielucha"]
stats["Beata Małecka-Libera"] += stats["Beata Małecka- Libera"]
del stats["Beata Małecka- Libera"]
stats["Bożena Borys-Szopa"] += stats["Bożena Borys- Szopa"]
del stats["Bożena Borys- Szopa"]
stats["Dorota Arciszewska-Mielewczyk"] += stats["Dorota Arciszewska- Mielewczyk"]
del stats["Dorota Arciszewska-Mielewczyk"]
stats["Joanna Kluzik-Rostkowska"] += stats["Joanna Kluzik- Rostkowska"]
del stats["Joanna Kluzik- Rostkowska"]
stats["Józefa Szczurek-Żelazko"] += stats["Józefa Szczurek- Żelazko"]
del stats["Józefa Szczurek- Żelazko"]
stats["Mirosława Stachowiak-Różecka"] += stats["Mirosława Stachowiak- Różecka"]
del stats["Mirosława Stachowiak- Różecka"]
stats["Szymon Szynkowski vel Sęk"] += stats["Szymon Szynkowski Vel Sęk"]
del stats["Szymon Szynkowski Vel Sęk"]
stats["Władysław Kosiniak-Kamysz"] += stats["Władysław Kosiniak- Kamysz"]
del stats["Władysław Kosiniak-Kamysz"]

# %%
## Manual data from missing files

missing = ['Barbara Bartuś', 'Barbara Bartuś', 'Włodzimierz Bernacki', 'Włodzimierz Bernacki', 'Jacek Bogucki', 
           'Jacek Bogucki', 'Lidia Burzyńska', 'Lidia Burzyńska', 'Anna Cicholska', 'Anna Cicholska', 
           'Andrzej Gawron', 'Andrzej Gawron', 'Konrad Głębocki', 'Konrad Głębocki', 'Kazimierz Gołojuch', 
           'Kazimierz Gołojuch', 'Mariusz Orion Jędrysek', 'Mariusz Orion Jędrysek', 'Piotr Kaleta', 'Piotr Kaleta', 
           'Henryk Kowalczyk', 'Henryk Kowalczyk', 'Elżbieta Kruk', 'Elżbieta Kruk', 'Joanna Lichocka', 
           'Joanna Lichocka', 'Tomasz Ławniczak', 'Tomasz Ławniczak', 'Marzena Machałek', 'Marzena Machałek', 
           'Anna Milczanowska', 'Anna Milczanowska', 'Jan Mosiński', 'Jan Mosiński', 'Kazimierz Moskal', 
           'Kazimierz Moskal', 'Jacek Osuch', 'Jacek Osuch', 'Stanisław Pięta', 'Stanisław Pięta', 
           'Stanisław Piotrowicz', 'Jolanta Szczypińska', 'Jolanta Szczypińska', 'Andrzej Szlachta', 
           'Andrzej Szlachta', 'Halina Szydełko', 'Halina Szydełko', 'Ewa Szymańska', 'Ewa Szymańska', 
           'Jan Szyszko', 'Jan Szyszko', 'Krzysztof Tchórzewski', 'Krzysztof Tchórzewski', 'Robert Telus', 
           'Robert Telus', 'Teresa Wargocka', 'Teresa Wargocka', 'Anna Zalewska', 'Anna Zalewska', 
           'Dorota Arciszewska-Mielewczyk', 'Piotr Łukasz Babiarz', 'Joanna Borowiak', 'Bożena Borys-Szopa', 
           'Anna Cicholska', 'Michał Cieślak', 'Przemysław Czarnecki', 'Anita Czerwińska', 'Leszek Dobrzyński', 
           'Ewa Filipiak', 'Jarosław Gonciarz', 'Jan Kilian', 'Ewa Kozanecka', 'Anna Krupka', 'Andrzej Kryj', 
           'Bernadeta Krynicka', 'Dariusz Kubiak', 'Krzysztof Kubów', 'Marek Kwitek', 'Bogdan Latosiński', 
           'Marzena Machałek', 'Krzysztof Maciejewski', 'Iwona Michałek', 'Aleksander Mrówczyński', 'Wojciech Murdzek', 
           'Anna Paluch', 'Jerzy Paul', 'Marek Polak', 'Mirosława Stachowiak-Różecka', 'Artur Szałabawka', 'Piotr Uruski', 
           'Krystyna Wróblewska', 'Joanna Augustynowska', 'Wojciech Bakun', 'Józef Brynkus', 'Grzegorz Furgo', 'Marta Golbik', 
           'Paweł Grabowski', 'Marek Jakubiak', 'Andrzej Kobylarz', 'Jerzy Kozłowski', 'Paweł Kukiz', 'Jakub Kulesa', 
           'Piotr Liroy-Marzec', 'Andrzej Maciejewski', 'Maciej Masłowski', 'Robert Mordak', 'Jarosław Porwich', 
           'Stefan Romecki', 'Marek Ruciński', 'Jarosław Sachajko', 'Paweł Skutecki', 'Paweł Szramka', 'Małgorzata Zwiercan']

# %%
for p in missing:
    stats[p] += 1

# %%
del stats['']

# %%
sorted_stats = sorted(stats.items(), key=lambda kv: kv[1], reverse=True)

# %%
for i, stat in enumerate(sorted_stats):
    print("{}. {}: {}".format(i+1, stat[0], stat[1]))
# Out:
# 1. Sylwester Tułajew: 133
# 2. Jerzy Gosiewski: 130
# 3. Waldemar Andzel: 125
# 4. Barbara Bartuś: 121
# 5. Piotr Kaleta: 117
# 6. Joanna Borowiak: 116
# 7. Kazimierz Moskal: 115
# 8. Barbara Dziuk: 112
# 9. Robert Telus: 108
# 10. Lidia Burzyńska: 104
# 11. Maria Zuba: 103
# 12. Ewa Szymańska: 102
# 13. Wojciech Skurkiewicz: 101
# 14. Tadeusz Woźniak: 100
# 15. Szymon Giżyński: 99
# 16. Bernadeta Krynicka: 96
# 17. Jarosław Gonciarz: 94
# 18. Jan Warzecha: 93
# 19. Jan Mosiński: 92
# 20. Ewa Tomaszewska: 89
# 21. Jan Kilian: 86
# 22. Jerzy Materna: 85
# 23. Piotr Uściński: 85
# 24. Jan Krzysztof Ardanowski: 82
# 25. Andrzej Kryj: 82
# 26. Leonard Krasulski: 82
# 27. Robert Kołakowski: 81
# 28. Krzysztof Szulowski: 79
# 29. Ryszard Bartosik: 76
# 30. Witold Czarnecki: 76
# 31. Andrzej Matusiewicz: 75
# 32. Aleksander Mrówczyński: 74
# 33. Bogdan Rzońca: 74
# 34. Mieczysław Miazga: 72
# 35. Piotr Uruski: 72
# 36. Anna Milczanowska: 72
# 37. Krzysztof Maciejewski: 71
# 38. Wojciech Zubowski: 71
# 39. Piotr Pyzik: 70
# 40. Adam Ołdakowski: 69
# 41. Wojciech Buczak: 67
# 42. Jerzy Małecki: 67
# 43. Elżbieta Duda: 67
# 44. Jan Duda: 63
# 45. Marzena Machałek: 63
# 46. Urszula Rusecka: 63
# 47. Ewa Filipiak: 62
# 48. Jacek Kurzępa: 61
# 49. Gabriela Masłowska: 61
# 50. Dariusz Kubiak: 61
# 51. Jolanta Szczypińska: 61
# 52. Grzegorz Adam Woźniak: 60
# 53. Sławomir Zawiślak: 60
# 54. Anna Kwiecień: 59
# 55. Czesław Sobierajski: 59
# 56. Marek Ast: 58
# 57. Anna Cicholska: 57
# 58. Jerzy Paul: 56
# 59. Marcin Porzucek: 56
# 60. Krystyna Wróblewska: 56
# 61. Jarosław Zieliński: 56
# 62. Alicja Kaczorowska: 56
# 63. Józef Leśniak: 56
# 64. Marek Polak: 55
# 65. Krzysztof Kubów: 55
# 66. Anita Czerwińska: 54
# 67. Bogdan Latosiński: 53
# 68. Robert Warwas: 53
# 69. Andrzej Kosztowniak: 52
# 70. Kazimierz Matuszny: 52
# 71. Przemysław Czarnecki: 50
# 72. Andrzej Gawron: 49
# 73. Paweł Lisiecki: 48
# 74. Rafał Weber: 48
# 75. Wojciech Murdzek: 47
# 76. Lech Kołakowski: 44
# 77. Ewa Malik: 44
# 78. Łukasz Schreiber: 44
# 79. Jerzy Wilk: 44
# 80. Katarzyna Czochara: 44
# 81. Małgorzata Golińska: 44
# 82. Jacek Falfus: 43
# 83. Anna Paluch: 43
# 84. Michał Jach: 43
# 85. Grzegorz Wojciechowski: 43
# 86. Piotr Babinetz: 43
# 87. Waldemar Buda: 42
# 88. Jarosław Szlachetka: 42
# 89. Marcin Horała: 42
# 90. Grzegorz Puda: 42
# 91. Arkadiusz Czartoryski: 41
# 92. Jacek Świat: 41
# 93. Jarosław Krajewski: 40
# 94. Leszek Galemba: 40
# 95. Dariusz Starzycki: 39
# 96. Józefa Hrynkiewicz: 38
# 97. Wiesław Krajewski: 38
# 98. Krzysztof Lipiec: 38
# 99. Piotr Polak: 37
# 100. Joanna Kopcińska: 36
# 101. Ewa Kozanecka: 35
# 102. Grzegorz Matusiak: 34
# 103. Dariusz Bąk: 34
# 104. Konrad Głębocki: 33
# 105. Anna Krupka: 33
# 106. Anna Schmidt-Rodziewicz: 33
# 107. Joanna Lichocka: 32
# 108. Dominik Tarczyński: 32
# 109. Jacek Sasin: 31
# 110. Halina Szydełko: 31
# 111. Stanisław Pięta: 31
# 112. Ryszard Terlecki: 31
# 113. Anna Czech: 31
# 114. Bożena Borys-Szopa: 30
# 115. Krystyna Pawłowicz: 29
# 116. Andrzej Szlachta: 29
# 117. Daniel Milewski: 28
# 118. Józefa Szczurek-Żelazko: 28
# 119. Kazimierz Gołojuch: 27
# 120. Teresa Hałas: 27
# 121. Marek Matuszewski: 27
# 122. Wojciech Kossakowski: 26
# 123. Marek Suski: 26
# 124. Grzegorz Janik: 26
# 125. Beata Mateusiak-Pielucha: 26
# 126. Kazimierz Smoliński: 26
# 127. Marek Kwitek: 25
# 128. Zbigniew Dolata: 24
# 129. Iwona Michałek: 24
# 130. Włodzimierz Bernacki: 22
# 131. Stanisław Szwed: 21
# 132. Michał Dworczyk: 21
# 133. Mirosława Stachowiak-Różecka: 21
# 134. Tadeusz Dziuba: 21
# 135. Michał Wojtkiewicz: 21
# 136. Krzysztof Jurgiel: 20
# 137. Jerzy Bielecki: 20
# 138. Elżbieta Kruk: 20
# 139. Teresa Glenc: 19
# 140. Jerzy Żyżyński: 19
# 141. Andrzej Smirnow: 19
# 142. Antoni Duda: 18
# 143. Janusz Śniadek: 18
# 144. Zbigniew Biernat: 18
# 145. Krzysztof Głuchowski: 18
# 146. Marek Opioła: 17
# 147. Zbigniew Chmielowiec: 17
# 148. Kazimierz Gwiazdowski: 17
# 149. Andrzej Melak: 17
# 150. Tomasz Ławniczak: 16
# 151. Piotr Łukasz Babiarz: 16
# 152. Artur Szałabawka: 16
# 153. Szymon Szynkowski vel Sęk: 16
# 154. Iwona Arent: 16
# 155. Elżbieta Rafalska: 16
# 156. Michał Cieślak: 15
# 157. Piotr Olszówka: 15
# 158. Wiesław Janczyk: 15
# 159. Beata Mazurek: 14
# 160. Dariusz Piontkowski: 13
# 161. Małgorzata Gosiewska: 13
# 162. Artur Soboń: 13
# 163. Zbigniew Babalski: 13
# 164. Bartłomiej Stawiarski: 13
# 165. Krzysztof Łapiński: 12
# 166. Agata Borowiec: 12
# 167. Łukasz Zbonikowski: 12
# 168. Tadeusz Cymański: 12
# 169. Grzegorz Schreiber: 11
# 170. Małgorzata Wypych: 11
# 171. Waldemar Olejniczak: 11
# 172. Edward Siarka: 10
# 173. Jan Szewczak: 10
# 174. Piotr Naimski: 10
# 175. Bartłomiej Wróblewski: 10
# 176. Arkadiusz Mularczyk: 10
# 177. Krzysztof Czabański: 9
# 178. Marek Zagórski: 8
# 179. Leszek Dobrzyński: 8
# 180. Henryk Kowalczyk: 8
# 181. Piotr Król: 8
# 182. Lech Sprawka: 7
# 183. Stanisław Piotrowicz: 7
# 184. Marta Kubiak: 7
# 185. Andrzej Kobylarz: 6
# 186. Andrzej Maciejewski: 6
# 187. Stefan Romecki: 6
# 188. Anna Elżbieta Sobecka: 5
# 189. Piotr Apel: 5
# 190. Wojciech Bakun: 5
# 191. Jakub Kulesza: 5
# 192. Maciej Masłowski: 5
# 193. Jarosław Sachajko: 5
# 194. Krzysztof Ostrowski: 5
# 195. Paweł Grabowski: 5
# 196. Paweł Szramka: 5
# 197. Izabela Katarzyna Mrzygłocka: 5
# 198. Monika Wielichowska: 5
# 199. Barbara Bubula: 4
# 200. Izabela Kloc: 4
# 201. Sylwester Chruszcz: 4
# 202. Norbert Kaczmarczyk: 4
# 203. Jarosław Porwich: 4
# 204. Tomasz Rzymkowski: 4
# 205. Stanisław Tyszka: 4
# 206. Jerzy Kozłowski: 4
# 207. Barbara Chrobak: 4
# 208. Agnieszka Ścigaj: 4
# 209. Teresa Wargocka: 4
# 210. Zofia Czernow: 4
# 211. Krzysztof Gadowski: 4
# 212. Cezary Grabarczyk: 4
# 213. Bożena Kamińska: 4
# 214. Zbigniew Konwiński: 4
# 215. Sławomir Neumann: 4
# 216. Małgorzata Niemczyk: 4
# 217. Tomasz Piotr Nowak: 4
# 218. Norbert Obrycki: 4
# 219. Jacek Bogucki: 4
# 220. Mariusz Orion Jędrysek: 4
# 221. Mariusz Trepka: 4
# 222. Danuta Nowicka: 4
# 223. Wojciech Jasiński: 4
# 224. Maciej Małecki: 3
# 225. Łukasz Rzepecki: 3
# 226. Elżbieta Borowska: 3
# 227. Grzegorz Długi: 3
# 228. Paweł Kukiz: 3
# 229. Mieczysław Kazimierz Baszko: 3
# 230. Tomasz Jaskóła: 3
# 231. Bartosz Józwiak: 3
# 232. Eugeniusz Kłopotek: 3
# 233. Kazimierz Kotowski: 3
# 234. Mirosław Maliszewski: 3
# 235. Krzysztof Paszyk: 3
# 236. Anna Maria Siarkowska: 3
# 237. Krzysztof Sitarski: 3
# 238. Zbigniew Sosnowski: 3
# 239. Genowefa Tokarska: 3
# 240. Piotr Zgorzelski: 3
# 241. Ireneusz Zyska: 3
# 242. Mieczysław Kasprzak: 3
# 243. Michał Wójcik: 3
# 244. Józef Brynkus: 3
# 245. Marek Jakubiak: 3
# 246. Robert Mordak: 3
# 247. Paweł Skutecki: 3
# 248. Elżbieta Zielińska: 3
# 249. Tadeusz Aziewicz: 3
# 250. Paweł Bańkowski: 3
# 251. Borys Budka: 3
# 252. Andrzej Czerwiński: 3
# 253. Grzegorz Furgo: 3
# 254. Elżbieta Gelert: 3
# 255. Marta Golbik: 3
# 256. Izabela Leszczyna: 3
# 257. Arkadiusz Marchewka: 3
# 258. Rajmund Miller: 3
# 259. Paweł Papke: 3
# 260. Elżbieta Radziszewska: 3
# 261. Marek Rząsa: 3
# 262. Krystyna Sibińska: 3
# 263. Bożena Szydłowska: 3
# 264. Anna Wasilewska: 3
# 265. Janusz Cichoń: 3
# 266. Joanna Fabisiak: 3
# 267. Jolanta Hibner: 3
# 268. Marek Hok: 3
# 269. Joanna Kluzik-Rostkowska: 3
# 270. Adam Korol: 3
# 271. Marcin Święcicki: 3
# 272. Ryszard Wilczyński: 3
# 273. Anna Zalewska: 3
# 274. Paweł Rychlik: 3
# 275. Iwona Ewa Arent: 2
# 276. Paweł Szefernaker: 2
# 277. Andrzej Jaworski: 2
# 278. Adam Andruszkiewicz: 2
# 279. Magdalena Błeńska: 2
# 280. Jacek Wilk: 2
# 281. Małgorzata Zwiercan: 2
# 282. Paweł Bejda: 2
# 283. Krystian Jarubas: 2
# 284. Jan Łopata: 2
# 285. Andżelika Możdżanowska: 2
# 286. Marek Sawicki: 2
# 287. Jerzy Jachnik: 2
# 288. Błażej Parda: 2
# 289. Wojciech Szarama: 2
# 290. Ewa Drozd: 2
# 291. Elżbieta Gapińska: 2
# 292. Jan Grabiec: 2
# 293. Agnieszka Hanajczyk: 2
# 294. Agnieszka Kołacz-Leszczyńska: 2
# 295. Tomasz Lenz: 2
# 296. Wojciech Wilk: 2
# 297. Marcin Duszek: 2
# 298. Bartosz Kownacki: 2
# 299. Adam Lipiński: 2
# 300. Krzysztof Zaremba: 2
# 301. Piotr Cieśliński: 2
# 302. Tomasz Kostuś: 2
# 303. Marek Krząkała: 2
# 304. Beata Małecka-Libera: 2
# 305. Katarzyna Osos: 2
# 306. Leszek Ruszczyk: 2
# 307. Jarosław Urbaniak: 2
# 308. Tomasz Latos: 2
# 309. Krzysztof Michałkiewicz: 2
# 310. Urszula Augustyn: 2
# 311. Robert Kropiwnicki: 2
# 312. Wojciech Król: 2
# 313. Arkadiusz Myrcha: 2
# 314. Kazimierz Plocke: 2
# 315. Michał Szczerba: 2
# 316. Marek Wójcik: 2
# 317. Sławomir Skwarek: 2
# 318. Elżbieta Teresa Płonka: 2
# 319. Zbigniew Ajchler: 2
# 320. Tomasz Głogowski: 2
# 321. Ewa Kołodziej: 2
# 322. Anna Nemś: 2
# 323. Grzegorz Raniewicz: 2
# 324. Marek Sowa: 2
# 325. Iwona Śledzińska-Katarasińska: 2
# 326. Andrzej Sośnierz: 2
# 327. Jacek Osuch: 2
# 328. Jan Szyszko: 2
# 329. Krzysztof Tchórzewski: 2
# 330. Mariusz Błaszczak: 1
# 331. Jarosław Stawiarski: 1
# 332. Grzegorz Tobiszowski: 1
# 333. Jacek Żalek: 1
# 334. Mariusz Kamiński: 1
# 335. Małgorzata Janowska: 1
# 336. Jan Klawiter: 1
# 337. Kornel Morawiecki: 1
# 338. Paweł Pudłowski: 1
# 339. Janusz Sanocki: 1
# 340. Robert Winnicki: 1
# 341. Jerzy Polaczek: 1
# 342. Adam Abramowicz: 1
# 343. Dorota Arciszewska- Mielewczyk: 1
# 344. Czesław Hoc: 1
# 345. Maks Kraczkowski: 1
# 346. Maciej Wąsik: 1
# 347. Jerzy Borowczak: 1
# 348. Stanisław Żmijan: 1
# 349. Elżbieta Witek: 1
# 350. Joanna Scheuring-Wielgus: 1
# 351. Artur Zasada: 1
# 352. Bartosz Arłukowicz: 1
# 353. Kinga Gajewska: 1
# 354. Zdzisław Gawlik: 1
# 355. Stanisław Gawłowski: 1
# 356. Rafał Grupiński: 1
# 357. Andrzej Halicki: 1
# 358. Ewa Kopacz: 1
# 359. Włodzimierz Nykiel: 1
# 360. Grzegorz Schetyna: 1
# 361. Tomasz Siemoniak: 1
# 362. Cezary Tomczyk: 1
# 363. Mariusz Witczak: 1
# 364. Artur Górski: 1
# 365. Adam Śnieżek: 1
# 366. Tomasz Zieliński: 1
# 367. Sławomir Jan Piechota: 1
# 368. Bogusław Sonik: 1
# 369. Patryk Jaki: 1
# 370. Grzegorz Raczak: 1
# 371. Rafał Wójcikowski: 1
# 372. Władysław Kosiniak- Kamysz: 1
# 373. Urszula Pasławska: 1
# 374. Jarosław Kaczyński: 1
# 375. Marek Kuchciński: 1
# 376. Krzysztof Brejza: 1
# 377. Tomasz Cimoszewicz: 1
# 378. Artur Dunin: 1
# 379. Waldy Dzikowski: 1
# 380. Lidia Gądek: 1
# 381. Artur Gierada: 1
# 382. Bożena Henczyca: 1
# 383. Maria Małgorzata Janyska: 1
# 384. Małgorzata Kidawa-Błońska: 1
# 385. Magdalena Kochan: 1
# 386. Henryka Krzywonos-Strycharska: 1
# 387. Tomasz Kucharski: 1
# 388. Józef Lassota: 1
# 389. Gabriela Lenartowicz: 1
# 390. Aldona Młyńczak: 1
# 391. Killion Munyama: 1
# 392. Dorota Niedziela: 1
# 393. Sławomir Nitras: 1
# 394. Mirosława Nykiel: 1
# 395. Marzena Okła- Drewnowicz: 1
# 396. Agnieszka Pomaska: 1
# 397. Jacek Protas: 1
# 398. Dorota Rutkowska: 1
# 399. Paweł Suski: 1
# 400. Krystyna Szumilas: 1
# 401. Marian Zembala: 1
# 402. Szymon Ziółkowski: 1
# 403. Dorota Arciszewska-Mielewczyk: 1
# 404. Joanna Augustynowska: 1
# 405. Jakub Kulesa: 1
# 406. Piotr Liroy-Marzec: 1
# 407. Marek Ruciński: 1
